# %%
import pandas as pd

df = pd.read_csv('datosMS-50.csv')
print(df)
df.to_html('Tabla-merge-sort.html')
# Out:
#     Tamanio    Mejor Caso     Peor Caso  Caso Promedio
# 0         0  2.000000e-07  0.000000e+00   0.000000e+00
# 1         1  0.000000e+00  0.000000e+00   0.000000e+00
# 2         2  7.000000e-07  2.000000e-06   3.000000e-07
# 3         3  6.000000e-07  4.000000e-07   4.000000e-07
# 4         4  8.000000e-07  6.000000e-07   6.000000e-07
# 5         5  1.400000e-06  8.000000e-07   8.000000e-07
# 6         6  1.200000e-06  1.100000e-06   1.000000e-06
# 7         7  1.600000e-06  1.400000e-06   1.300000e-06
# 8         8  1.600000e-06  1.500000e-06   1.600000e-06
# 9         9  2.200000e-06  1.800000e-06   1.800000e-06
# 10       10  2.200000e-06  1.900000e-06   2.400000e-06
# 11       11  2.500000e-06  2.100000e-06   2.300000e-06
# 12       12  2.700000e-06  2.300000e-06   2.500000e-06
# 13       13  2.900000e-06  2.600000e-06   2.800000e-06
# 14       14  3.300000e-06  3.200000e-06   2.800000e-06
# 15       15  3.300000e-06  2.800000e-06   3.000000e-06
# ...
